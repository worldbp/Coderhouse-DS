# %%
#las librerias que uso las tengo instaladas localmente en el env de miniconda
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas import read_csv
from pathlib import Path
import os
from os import chdir
import ipywidgets as widgets
from ipywidgets import interact, interact_manual
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %% [markdown]
# ## Abstracto
#
#
# Este trabajo explora el potencial de aprovechar los datos de Glassdoor mediante algoritmos de machine learning. A pesar de desafíos como la tendencia a reseñas negativas y la falta de verificación de la experiencia laboral, los algoritmos pueden analizar patrones en las opiniones de los empleados para predecir tendencias y evaluar la satisfacción laboral.Utilizando algoritmos de aprendizaje supervisado, nos enfocaremos en técnicas de regresión para analizar patrones complejos en las opiniones de los empleados. Estos algoritmos nos permitirán identificar correlaciones entre variables clave, como los rangos salariales y las puntuaciones de reseñas, arrojando luz sobre cómo factores como el salario impactan directamente en la satisfacción laboral.
# Además, implementaremos algoritmos de procesamiento del lenguaje natural (NLP) para analizar las reseñas cualitativas de los empleados. Al desglosar estos datos no estructurados, podremos extraer sentimientos y temas clave, transformando las experiencias subjetivas en información objetiva y cuantificable para nuestro análisis de regresión. Este enfoque integrado nos permitirá comprender no sólo las tendencias generales, sino también los matices sutiles en las opiniones de los empleados, lo que se traduce en una toma de decisiones empresariales más precisa y perspicaz.
# Al aprovechar estas técnicas de machine learning, Glassdoor se convierte en una poderosa herramienta para la toma de decisiones. No sólo se puede usar para anticipar problemas de la empresa sino mejorar la retención de talento, sino también fortalecer las estrategias de marketing y mejorar el clima laboral. Esta integración de datos cualitativos y cuantitativos, combinada con la precisión del aprendizaje supervisado, redefine cómo las empresas pueden entender y responder a las percepciones de sus empleados, impulsando así un cambio significativo en el panorama empresarial.
#
#
# ### **Contexto empresarial:**
# Glassdoor se ha convertido en la única plataforma que permite ver a profesionales que buscan oportunidades laborales o que quieren tener una idea de una compañía o un punto de comparación a otras. Esta ventaja de mercado la convierte en la única fuente de opiniones  sobre cultura corporativa, rangos de salarios, etc. Está posición dominante lo hace una fuente única de información, además de ser un portal de empleo donde las personas que van aplicar, van a tener una reseña de la empresa a la cual van aplicar.
#
#
# ### **Problema empresarial:**
#  Para cualquier compañía tener referencias es importante y a través de está información se puede hacer un modelo que ayude a ver qué variables predicen mejor la  tenencia de una opinión muy desfavorable o muy positiva. Este recurso es vital para las empresas al permitirles anticipar necesidades de fuerza laboral, fortalecer áreas clave y mejorar estrategias de atracción y retención de talento útil para anticiparse a las necesidades de tu fuerza de trabajo, reforzar áreas donde puedes crear un fuerte impacto en el esfuerzo de atracción y retención de talento y además de ser una herramienta de mercadeo de la empresa.
#
#
# ### **Problema analítico:**
# A continuación, analizamos algunos aspectos a considerar. Glassdoor, una plataforma líder en el mercado, proporciona valiosas opiniones sobre empresas, salarios y cultura corporativa, siendo una fuente crucial para profesionales y empleadores. Sin embargo, enfrenta desafíos, como la tendencia a reseñas negativas, especialmente tras despidos masivos, y la falta de verificación de la experiencia laboral de los usuarios. A pesar de estas limitaciones, Glassdoor sigue siendo una fuente única y pública de información en un mercado laboral opaco. El dataset tiene un foco específico en el mercado laboral del Reino Unido.
# ####	**Solución Propuesta:**
# Para afrontar este problema analítico y aprovechar al máximo el potencial de los datos recopilados en Glassdoor, vamos a utilizar técnicas avanzadas de Machine Learning, específicamente aprendizaje supervisado. Nuestro objetivo principal es predecir la variable overall_rating (puntaje promedio) de las empresas basándonos en diversas características proporcionadas en las reseñas y perfiles de las empresas.
# #### **Enfoque de Aprendizaje Supervisado**:
# En el contexto del aprendizaje supervisado, utilizaremos algoritmos de regresión para construir un modelo predictivo robusto. Estos algoritmos analizarán las características como el número de reseñas, el salario promedio, la satisfacción del empleado y otros factores relevantes para entender las relaciones complejas entre estas variables y el puntaje promedio de la empresa.
# Aplicaremos técnicas de preprocesamiento de datos para limpiar y transformar los datos en un formato adecuado para el modelado. Utilizaremos técnicas de selección de características para identificar las variables más influyentes en la predicción del overall_rating. Posteriormente, evaluaremos varios algoritmos de regresión y ajustaremos sus hiper-parámetros para encontrar el modelo más preciso y generalizable.
# Finalmente, validamos nuestro modelo utilizando técnicas como la validación cruzada para asegurarnos de su robustez y capacidad para generalizar datos no vistos. Este enfoque de aprendizaje supervisado nos permitirá proporcionar insights valiosos y precisos sobre la calidad laboral de las empresas en el mercado del Reino Unido, ayudando tanto a profesionales como a empleadores a tomar decisiones más informadas y estratégicas.
# Regenerate
#
# ### **Comprende**:
#
#  1.   **date_review:**   Fecha en la que se realizó la reseña.
#  2.   **job_title:**     Rol dentro de la empresa.
#  3.   **current:**        Estatus dentro de la empresa actual.
#  4.  **location:**        Lugar de la empresa (ciudad).
#  5.  **overall_rating:** puntuación total de la empresa (entre 1-5).
#  6.   **work_life_balance:**  opinión del equilibrio entre la vida y del trabajo (1-5)
#  7.   **culture_values:**   opinión de la cultura empresarial (1-5)
#  8.   **diversity_inclusion:**  apreciación sobre el nivel de diversidad e inclusión (1-5)
#  9.   **career_opp:** opinión sobre oportunidades dentro de la empresa (1-5)
#  10.  ***comp_benefits:**   opinión sobre compensación y beneficios (1-5)
#  11.  **senior_mgmt:**  apreciación sobre los directivos de la empresa (1-5).
#  12.  **recommend:**   apreciación sobre si recomendarías esta compañia ("mucho","normal", "malo").
#  13.  **ceo_approv:** apreciación sobre el CEO o dueño de la compañia ("mucho","normal", "malo")..
#  14.  **outlook:**  apreciación sobre el futuro de la empresa ("mucho","normal", "malo").
#  15.  **headline:** comentario a manera de título sobre la empresa.
#  16.  **pros:** comentarios positivos sobre la empresa.
#  17.  **cons:** comentarios negativos sobre la empresa.
#
#
# ## ***Hipotésis:***
#
#  Qué factores ayudan a predecir una buena o mala puntuación sobre una comapañia?
#
#  ### **Preguntas secundarias:**
#  1. Cuál es el área de más preocupación para una empresa?
#  2.  Hay una relación entre algunos de estos factores o son indepndientes?
#  3. Afecta el rol en lo que se valora más?
#  4.  Estas variables son las mismas dependiendo del tipo de compañia o el sector?
#  5. Se puede hacer un perfil de valoración por empresa?

# %%
# os.chdir("C:/Users/Rodolfo/Downloads")
# os.getcwd()

# glassdoor_reviews:

googleSheetId = '1Ep8fVrEiaURMXTvh8QgHGmnutUzus0lOUhMEcNUkGIs'
workSheetName = 'reviews'

url ='https://docs.google.com/spreadsheets/d/{0}/gviz/tq?tqx=out:csv&sheet={1}'.format(
    googleSheetId,
    workSheetName
)


print(url)
# industries:
# https://docs.google.com/spreadsheets/d/1NxVL_c17vpUwiaUS72n0SV9-OvCrOKNIUREFKdSHM2Q/edit?usp=share_link
googleSheetId2 = '1NxVL_c17vpUwiaUS72n0SV9-OvCrOKNIUREFKdSHM2Q'
workSheetName2 = 'industries'
url2 ='https://docs.google.com/spreadsheets/d/{0}/gviz/tq?tqx=out:csv&sheet={1}'.format(
    googleSheetId2,
    workSheetName2
)
# Out:
# https://docs.google.com/spreadsheets/d/1Ep8fVrEiaURMXTvh8QgHGmnutUzus0lOUhMEcNUkGIs/gviz/tq?tqx=out:csv&sheet=reviews

# %%
df = read_csv(url)
industries = read_csv(url2)

# %%
df.head(8)
# Out:
#                     firm date_review             job_title  \
# 0  AFH-Wealth-Management  2015-04-05                   NaN
# 1  AFH-Wealth-Management  2015-12-11  Office Administrator
# 2  AFH-Wealth-Management  2016-01-28  Office Administrator
# 3  AFH-Wealth-Management  2016-04-16                   NaN
# 4  AFH-Wealth-Management  2016-04-23  Office Administrator
# 5  AFH-Wealth-Management  2016-05-26  Office Administrator
# 6  AFH-Wealth-Management  2016-09-23                   IFA
# 7  AFH-Wealth-Management  2016-09-25    Anonymous Employee
#
#                                current                      location  \
# 0                     Current Employee                           NaN
# 1   Current Employee, more than 1 year  Bromsgrove, England, England
# 2   Current Employee, less than 1 year  Bromsgrove, England, England
# 3                     Current Employee                           NaN
# 4   Current Employee, more than 1 year  Bromsgrove, England, England
# 5   Current Employee, less than 1 year                           NaN
# 6                      Former Employee  Bromsgrove, England, England
# 7  Current Employee, more than 5 years              Century City, CA
#
#    overall_rating  work_life_balance  culture_values  diversity_inclusion  \
# 0               2                4.0             3.0                  NaN
# 1               2                3.0             1.0                  NaN
# 2               1                1.0             1.0                  NaN
# 3               5                2.0             3.0                  NaN
# 4               1                2.0             1.0                  NaN
# 5               3                4.0             2.0                  NaN
# 6               1                1.0             1.0                  NaN
# 7               5                5.0             5.0                  NaN
#
#    career_opp  comp_benefits  senior_mgmt recommend ceo_approv outlook  \
# 0         2.0            3.0          3.0         x          o       r
# 1         2.0            1.0          4.0         x          o       r
# 2         1.0            1.0          1.0         x          o       x
# 3         2.0            2.0          3.0         x          o       r
# 4         2.0            1.0          1.0         x          o       x
# 5         2.0            3.0          2.0         o          r       r
# 6         1.0            1.0          1.0         x          o       r
# 7         5.0            4.0          5.0         v          o       v
#
#                                   headline  \
# 0  Young colleagues, poor micro management
# 1             Excellent staff, poor salary
# 2          Low salary, bad micromanagement
# 3            Over promised under delivered
# 4                   client reporting admin
# 5                     Office administrator
# 6                   It horrible management
# 7                       Good place to work
#
#                                                 pros  \
# 0  Very friendly and welcoming to new staff. Easy...
# 1      Friendly, helpful and hard-working colleagues
# 2  Easy to get the job even without experience in...
# 3                            Nice staff to work with
# 4              Easy to get the job, Nice colleagues.
# 5  Some good people to work with.\n\nFlexible wor...
# 6  Good investment management strategy. Overall t...
# 7  The people are great and the culture is very f...
#
#                                                 cons
# 0    Poor salaries, poor training and communication.
# 1  Poor salary which doesn't improve much with pr...
# 2  Very low salary, poor working conditions, very...
# 3           No career progression and salary is poor
# 4  Abysmal pay, around minimum wage. No actual tr...
# 5  Morale.\n\nLack of managerial structure.\n\nDo...
# 6  The management and seniors are ruthless. No tr...
# 7  Wouldn't necessarily say there are any cons to...

# %%
df.describe()

df.columns
# Out:
# Index(['firm', 'date_review', 'job_title', 'current', 'location',
#        'overall_rating', 'work_life_balance', 'culture_values',
#        'diversity_inclusion', 'career_opp', 'comp_benefits', 'senior_mgmt',
#        'recommend', 'ceo_approv', 'outlook', 'headline', 'pros', 'cons'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286374 entries, 0 to 286373
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   firm                 286374 non-null  object
#  1   date_review          286374 non-null  object
#  2   job_title            259076 non-null  object
#  3   current              286374 non-null  object
#  4   location             188642 non-null  object
#  5   overall_rating       286374 non-null  int64
#  6   work_life_balance    238886 non-null  float64
#  7   culture_values       224590 non-null  float64
#  8   diversity_inclusion  47964 non-null   float64
#  9   career_opp           239451 non-null  float64
#  10  comp_benefits        238888 non-null  float64
#  11  senior_mgmt          237138 non-null  float64
#  12  recommend            286374 non-null  object
#  13  ceo_approv           286374 non-null  object
#  14  outlook              286374 non-null  object
#  15  headline             285570 non-null  object
#  16  pros                 286374 non-null  object
#  17  cons                 286370 non-null  object
# dtypes: float64(6), int64(1), object(11)
# memory usage: 39.3+ MB

# %% [markdown]
# > A simple vista podemos observar que hay las columnas de "location" y "diversity_inclusion" tienen un numero importante de valores nulos. Lo cual puede hacer su uso en un modelo dificil. También hay columnas, como "job_title", que tienen valores vacios que hay que manejar. Primero convirtiendolos en nulos y después, dependiendo de la cantidad, ver que estrategía utilizar para poder aprovecharlos.

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Duplicados

# %%
print(df.duplicated().value_counts(),'\n\n',round(df.duplicated().value_counts()/df.shape[0]*100))
# Out:
# False    277206
# True       9168
# dtype: int64
#
#  False    97.0
# True      3.0
# dtype: float64

# %% [markdown]
# ##### Conclusión:
#
# El tres por ciento de los datos está duplicado, se puede obtar por eliminar estos registros para no influenciar nuestro modelo.

# %%
df = df.drop_duplicates()
print(df.shape)
# Out:
# (277206, 18)

# %% [markdown]
# #### Missing Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 277206 entries, 0 to 286373
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   firm                 277206 non-null  object
#  1   date_review          277206 non-null  object
#  2   job_title            250813 non-null  object
#  3   current              277206 non-null  object
#  4   location             182782 non-null  object
#  5   overall_rating       277206 non-null  int64
#  6   work_life_balance    231391 non-null  float64
#  7   culture_values       217605 non-null  float64
#  8   diversity_inclusion  46453 non-null   float64
#  9   career_opp           231942 non-null  float64
#  10  comp_benefits        231393 non-null  float64
#  11  senior_mgmt          229709 non-null  float64
#  12  recommend            277206 non-null  object
#  13  ceo_approv           277206 non-null  object
#  14  outlook              277206 non-null  object
#  15  headline             276435 non-null  object
#  16  pros                 277206 non-null  object
#  17  cons                 277202 non-null  object
# dtypes: float64(6), int64(1), object(11)
# memory usage: 40.2+ MB

# %% [markdown]
# ### Industria

# %%
industries['firm'] = industries['firm'].str.replace("'","",)
industries.head()

#genero un diccionario key-value
industry_dict = dict(zip(industries['firm'], industries['industry']))


#lo uso para mapear los valores a cada una de las compañias
df['industry'] = df['firm'].map(industry_dict)

# %% [markdown]
# ####  Outlook, Recommend, CEO_Approv:
# Para poder realizar nuestro análisis supervisado, vamos a tener que convertir algunas de nuestras variables cualitativas que tienen carácter ordinal en variables númericas para su procesamiento.
# Las recomendaciones de la compañia , CEO , y futuro de la empresa le han colocado las categorías v, r, x, and o, con el siguiente significado:
# v - Positivo, r - Más o Menos, x - Negativo, o - Sin opinión
#
# A continuación exploraremos esas variables para entender su comportamiento:

# %%
ordinales = ['recommend', 'ceo_approv', 'outlook']
df_ordinales = df[ordinales]
print(
    df_ordinales['recommend'].value_counts()/len(df_ordinales)*100, '\n\n',

    df_ordinales['ceo_approv'].value_counts()/len(df_ordinales)*100, '\n\n',

    df_ordinales['outlook'].value_counts()/len(df_ordinales)*100

)
# Out:
# v    51.786758
# o    26.823373
# x    21.389869
# Name: recommend, dtype: float64
#
#  o    35.868993
# v    35.716038
# r    21.525508
# x     6.889461
# Name: ceo_approv, dtype: float64
#
#  v    37.282743
# o    33.929641
# r    18.152565
# x    10.635051
# Name: outlook, dtype: float64

# %%
dict_ordinal_cat = {'v': 3, 'x': 1, 'r': 2, 'o': np.NaN }

for col in df_ordinales.columns:
    print(col)
    df_ordinales.loc[:,f'{col}']= df_ordinales.loc[:,f'{col}'].map(dict_ordinal_cat)

print(
    df_ordinales['recommend'].value_counts()/len(df_ordinales)*100, '\n\n',

    df_ordinales['ceo_approv'].value_counts()/len(df_ordinales)*100, '\n\n',

    df_ordinales['outlook'].value_counts()/len(df_ordinales)*100

)
# for col in df_ordinales.columns:
#     print(col)
#     df_ordinales.loc[f]= df_ordinales[f'{col}'].map(dict_ordinal_cat)


print(
    df_ordinales['recommend'].value_counts()/len(df_ordinales)*100, '\n\n',

    df_ordinales['ceo_approv'].value_counts()/len(df_ordinales)*100, '\n\n',

    df_ordinales['outlook'].value_counts()/len(df_ordinales)*100

)

df_train = df
df_train[ordinales]= df_ordinales

df_train.head()
# Out:
# recommend
# ceo_approv
# outlook
# 3.0    51.786758
# 1.0    21.389869
# Name: recommend, dtype: float64
#
#  3.0    35.716038
# 2.0    21.525508
# 1.0     6.889461
# Name: ceo_approv, dtype: float64
#
#  3.0    37.282743
# 2.0    18.152565
# 1.0    10.635051
# Name: outlook, dtype: float64
# 3.0    51.786758
# 1.0    21.389869
# Name: recommend, dtype: float64
#
#  3.0    35.716038
# 2.0    21.525508
# 1.0     6.889461
# Name: ceo_approv, dtype: float64
#
#  3.0    37.282743
# 2.0    18.152565
# 1.0    10.635051
# Name: outlook, dtype: float64
# <ipython-input-12-fb8749fc12a1>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ordinales.loc[:,f'{col}']= df_ordinales.loc[:,f'{col}'].map(dict_ordinal_cat)
# <ipython-input-12-fb8749fc12a1>:5: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_ordinales.loc[:,f'{col}']= df_ordinales.loc[:,f'{col}'].map(dict_ordinal_cat)
# <ipython-input-12-fb8749fc12a1>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ordinales.loc[:,f'{col}']= df_ordinales.loc[:,f'{col}'].map(dict_ordinal_cat)
# <ipython-input-12-fb8749fc12a1>:5: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_ordinales.loc[:,f'{col}']= df_ordinales.loc[:,f'{col}'].map(dict_ordinal_cat)
# <ipython-input-12-fb8749fc12a1>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ordinales.loc[:,f'{col}']= df_ordinales.loc[:,f'{col}'].map(dict_ordinal_cat)
# <ipython-input-12-fb8749fc12a1>:5: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_ordinales.loc[:,f'{col}']= df_ordinales.loc[:,f'{col}'].map(dict_ordinal_cat)
#                     firm date_review             job_title  \
# 0  AFH-Wealth-Management  2015-04-05                   NaN
# 1  AFH-Wealth-Management  2015-12-11  Office Administrator
# 2  AFH-Wealth-Management  2016-01-28  Office Administrator
# 3  AFH-Wealth-Management  2016-04-16                   NaN
# 4  AFH-Wealth-Management  2016-04-23  Office Administrator
#
#                               current                      location  \
# 0                    Current Employee                           NaN
# 1  Current Employee, more than 1 year  Bromsgrove, England, England
# 2  Current Employee, less than 1 year  Bromsgrove, England, England
# 3                    Current Employee                           NaN
# 4  Current Employee, more than 1 year  Bromsgrove, England, England
#
#    overall_rating  work_life_balance  culture_values  diversity_inclusion  \
# 0               2                4.0             3.0                  NaN
# 1               2                3.0             1.0                  NaN
# 2               1                1.0             1.0                  NaN
# 3               5                2.0             3.0                  NaN
# 4               1                2.0             1.0                  NaN
#
#    career_opp  comp_benefits  senior_mgmt  recommend  ceo_approv  outlook  \
# 0         2.0            3.0          3.0        1.0         NaN      2.0
# 1         2.0            1.0          4.0        1.0         NaN      2.0
# 2         1.0            1.0          1.0        1.0         NaN      1.0
# 3         2.0            2.0          3.0        1.0         NaN      2.0
# 4         2.0            1.0          1.0        1.0         NaN      1.0
#
#                                   headline  \
# 0  Young colleagues, poor micro management
# 1             Excellent staff, poor salary
# 2          Low salary, bad micromanagement
# 3            Over promised under delivered
# 4                   client reporting admin
#
#                                                 pros  \
# 0  Very friendly and welcoming to new staff. Easy...
# 1      Friendly, helpful and hard-working colleagues
# 2  Easy to get the job even without experience in...
# 3                            Nice staff to work with
# 4              Easy to get the job, Nice colleagues.
#
#                                                 cons industry
# 0    Poor salaries, poor training and communication.  Finance
# 1  Poor salary which doesn't improve much with pr...  Finance
# 2  Very low salary, poor working conditions, very...  Finance
# 3           No career progression and salary is poor  Finance
# 4  Abysmal pay, around minimum wage. No actual tr...  Finance

# %%
val_nulos  = df_train.isnull().sum()
nulos_pct = round(val_nulos/ df.shape[0]*100, 2)

df_nulos = pd.DataFrame({
    'Cant_Nulos': val_nulos,
    'Pct_Nulos':    nulos_pct
})

df_nulos= df_nulos.loc[df_nulos['Cant_Nulos']> 0].sort_values(by='Cant_Nulos', ascending=False)
print(df_nulos)
# Out:
#                      Cant_Nulos  Pct_Nulos
# diversity_inclusion      230753      83.24
# ceo_approv                99431      35.87
# location                  94424      34.06
# outlook                   94055      33.93
# recommend                 74356      26.82
# culture_values            59601      21.50
# senior_mgmt               47497      17.13
# work_life_balance         45815      16.53
# comp_benefits             45813      16.53
# career_opp                45264      16.33
# job_title                 26393       9.52
# headline                    771       0.28
# cons                          4       0.00

# %%
import plotly.graph_objects as go

fig = go.Figure(go.Bar(
            x=df_nulos['Cant_Nulos'],
            y=df_nulos.index,
            orientation='h'))

fig.update_layout(
    title=go.layout.Title(
        text="Missing values<br><sup> De Menor a Mayor</sup>",

    ),

    xaxis=go.layout.XAxis(
        title=go.layout.xaxis.Title(
            text=" Cant. Valores nulos"
            )
        ))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ef2ad0e8-05b9-45ff-a078-f460ceed4cc8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef2ad0e8-05b9-45ff-a078-f460ceed4cc8")) {                    Plotly.newPlot(                        "ef2ad0e8-05b9-45ff-a078-f460ceed4cc8",                        [{"orientation":"h","x":[230753,99431,94424,94055,74356,59601,47497,45815,45813,45264,26393,771,4],"y":["diversity_inclusion","ceo_approv","location","outlook","recommend","culture_values","senior_mgmt","work_life_balance","comp_benefits","career_opp","job_title","headline","cons"],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewi ...

# %% [markdown]
# #####   1. Eliminar features con más del 50% de valores pérdidos

# %%
col_del = ['diversity_inclusion']
df_train = df_train.drop(labels=col_del, axis=1)

# %% [markdown]
# #####   2. Eliminar filas con menos del 1% de valores pérdidos

# %%
cols_del = ['headline','pros','cons']
df_train.dropna(subset=cols_del, inplace=True, axis=0)
df_train.head()
# Out:
#                     firm date_review             job_title  \
# 0  AFH-Wealth-Management  2015-04-05                   NaN
# 1  AFH-Wealth-Management  2015-12-11  Office Administrator
# 2  AFH-Wealth-Management  2016-01-28  Office Administrator
# 3  AFH-Wealth-Management  2016-04-16                   NaN
# 4  AFH-Wealth-Management  2016-04-23  Office Administrator
#
#                               current                      location  \
# 0                    Current Employee                           NaN
# 1  Current Employee, more than 1 year  Bromsgrove, England, England
# 2  Current Employee, less than 1 year  Bromsgrove, England, England
# 3                    Current Employee                           NaN
# 4  Current Employee, more than 1 year  Bromsgrove, England, England
#
#    overall_rating  work_life_balance  culture_values  career_opp  \
# 0               2                4.0             3.0         2.0
# 1               2                3.0             1.0         2.0
# 2               1                1.0             1.0         1.0
# 3               5                2.0             3.0         2.0
# 4               1                2.0             1.0         2.0
#
#    comp_benefits  senior_mgmt  recommend  ceo_approv  outlook  \
# 0            3.0          3.0        1.0         NaN      2.0
# 1            1.0          4.0        1.0         NaN      2.0
# 2            1.0          1.0        1.0         NaN      1.0
# 3            2.0          3.0        1.0         NaN      2.0
# 4            1.0          1.0        1.0         NaN      1.0
#
#                                   headline  \
# 0  Young colleagues, poor micro management
# 1             Excellent staff, poor salary
# 2          Low salary, bad micromanagement
# 3            Over promised under delivered
# 4                   client reporting admin
#
#                                                 pros  \
# 0  Very friendly and welcoming to new staff. Easy...
# 1      Friendly, helpful and hard-working colleagues
# 2  Easy to get the job even without experience in...
# 3                            Nice staff to work with
# 4              Easy to get the job, Nice colleagues.
#
#                                                 cons industry
# 0    Poor salaries, poor training and communication.  Finance
# 1  Poor salary which doesn't improve much with pr...  Finance
# 2  Very low salary, poor working conditions, very...  Finance
# 3           No career progression and salary is poor  Finance
# 4  Abysmal pay, around minimum wage. No actual tr...  Finance

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 276431 entries, 0 to 286372
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   firm               276431 non-null  object
#  1   date_review        276431 non-null  object
#  2   job_title          250087 non-null  object
#  3   current            276431 non-null  object
#  4   location           182199 non-null  object
#  5   overall_rating     276431 non-null  int64
#  6   work_life_balance  230945 non-null  float64
#  7   culture_values     217191 non-null  float64
#  8   career_opp         231493 non-null  float64
#  9   comp_benefits      230946 non-null  float64
#  10  senior_mgmt        229264 non-null  float64
#  11  recommend          202488 non-null  float64
#  12  ceo_approv         177471 non-null  float64
#  13  outlook            182837 non-null  float64
#  14  headline           276431 non-null  object
#  15  pros               276431 non-null  object
#  16  cons               276431 non-null  object
#  17  industry           276431 non-null  object
# dtypes: float64(8), int64(1), object(9)
# memory usage: 40.1+ MB

# %%
df_numerical_features = df_train.select_dtypes(exclude='object')
df_categorical_features = df_train.select_dtypes(include='object')

# %%
df_categorical_features
# Out:
#                          firm date_review                    job_title  \
# 0       AFH-Wealth-Management  2015-04-05                          NaN
# 1       AFH-Wealth-Management  2015-12-11         Office Administrator
# 2       AFH-Wealth-Management  2016-01-28         Office Administrator
# 3       AFH-Wealth-Management  2016-04-16                          NaN
# 4       AFH-Wealth-Management  2016-04-23         Office Administrator
# ...                       ...         ...                          ...
# 286368                 Google  2009-05-06  Software Engineering Intern
# 286369                 Google  2009-05-10                   Accountant
# 286370                 Google  2009-05-10            Software Engineer
# 286371                 Google  2009-05-11  Associate Financial Analyst
# 286372                 Google  2009-05-12     Senior Software Engineer
#
#                                    current                      location  \
# 0                         Current Employee                           NaN
# 1       Current Employee, more than 1 year  Bromsgrove, England, England
# 2       Current Employee, less than 1 year  Bromsgrove, England, England
# 3                         Current Employee                           NaN
# 4       Current Employee, more than 1 year  Bromsgrove, England, England
# ...                                    ...                           ...
# 286368                     Former Employee             Mountain View, CA
# 286369                     Former Employee                           NaN
# 286370                    Current Employee             Mountain View, CA
# 286371                    Current Employee             Mountain View, CA
# 286372                     Former Employee             Mountain View, CA
#
#                                                  headline  \
# 0                 Young colleagues, poor micro management
# 1                            Excellent staff, poor salary
# 2                         Low salary, bad micromanagement
# 3                           Over promised under delivered
# 4                                  client reporting admin
# ...                                                   ...
# 286368                       Depends on where you end up.
# 286369                                        Great place
# 286370      Big company with pockets of start-up projects
# 286371  Great people, Great intentions, sometimes bori...
# 286372    Good place to work if you like large companies.
#
#                                                      pros  \
# 0       Very friendly and welcoming to new staff. Easy...
# 1           Friendly, helpful and hard-working colleagues
# 2       Easy to get the job even without experience in...
# 3                                 Nice staff to work with
# 4                   Easy to get the job, Nice colleagues.
# ...                                                   ...
# 286368  The perks, food and transportation being the m...
# 286369  I've also heard about how Google's stack ranki...
# 286370  Your colleagues are smart, motivated, inventiv...
# 286371  Benefits of course. Free food, free transporta...
# 286372  Great work environment. Especially software en...
#
#                                                      cons industry
# 0         Poor salaries, poor training and communication.  Finance
# 1       Poor salary which doesn't improve much with pr...  Finance
# 2       Very low salary, poor working conditions, very...  Finance
# 3                No career progression and salary is poor  Finance
# 4       Abysmal pay, around minimum wage. No actual tr...  Finance
# ...                                                   ...      ...
# 286368  My experience was that of an intern so it may ...       IT
# 286369  A few years ago during the internet boom we al...       IT
# 286370  Big company syndrome. We have dozens of VPs an...       IT
# 286371  Mundane work. If you are not an engineer, you ...       IT
# 286372  Little influence on which area you get assigne...       IT
#
# [276431 rows x 9 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.impute import SimpleImputer
from math import sqrt
from sklearn.preprocessing import LabelEncoder
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.model_selection import train_test_split


cols_encoded =['firm','job_title', 'current','location','industry']
df_categorical_features.loc[:,cols_encoded] = df_categorical_features.loc[:,cols_encoded].apply(lambda series: pd.Series(
    LabelEncoder().fit_transform(series[series.notnull()]),
    index=series[series.notnull()].index
), )

df_categorical_features.loc[:,cols_encoded] = df_categorical_features.loc[:,cols_encoded].apply(lambda x:x+1)

# %%
df_categorical_features
# Out:
#          firm date_review job_title current location  \
# 0         1.0  2015-04-05       NaN     1.0      NaN
# 1         1.0  2015-12-11   16243.0     3.0    805.0
# 2         1.0  2016-01-28   16243.0     2.0    805.0
# 3         1.0  2016-04-16       NaN     1.0      NaN
# 4         1.0  2016-04-23   16243.0     3.0    805.0
# ...       ...         ...       ...     ...      ...
# 286368  149.0  2009-05-06   23261.0     9.0   3821.0
# 286369  149.0  2009-05-10    1331.0     9.0      NaN
# 286370  149.0  2009-05-10   23218.0     1.0   3821.0
# 286371  149.0  2009-05-11    2880.0     1.0   3821.0
# 286372  149.0  2009-05-12   22395.0     9.0   3821.0
#
#                                                  headline  \
# 0                 Young colleagues, poor micro management
# 1                            Excellent staff, poor salary
# 2                         Low salary, bad micromanagement
# 3                           Over promised under delivered
# 4                                  client reporting admin
# ...                                                   ...
# 286368                       Depends on where you end up.
# 286369                                        Great place
# 286370      Big company with pockets of start-up projects
# 286371  Great people, Great intentions, sometimes bori...
# 286372    Good place to work if you like large companies.
#
#                                                      pros  \
# 0       Very friendly and welcoming to new staff. Easy...
# 1           Friendly, helpful and hard-working colleagues
# 2       Easy to get the job even without experience in...
# 3                                 Nice staff to work with
# 4                   Easy to get the job, Nice colleagues.
# ...                                                   ...
# 286368  The perks, food and transportation being the m...
# 286369  I've also heard about how Google's stack ranki...
# 286370  Your colleagues are smart, motivated, inventiv...
# 286371  Benefits of course. Free food, free transporta...
# 286372  Great work environment. Especially software en...
#
#                                                      cons industry
# 0         Poor salaries, poor training and communication.      5.0
# 1       Poor salary which doesn't improve much with pr...      5.0
# 2       Very low salary, poor working conditions, very...      5.0
# 3                No career progression and salary is poor      5.0
# 4       Abysmal pay, around minimum wage. No actual tr...      5.0
# ...                                                   ...      ...
# 286368  My experience was that of an intern so it may ...     10.0
# 286369  A few years ago during the internet boom we al...     10.0
# 286370  Big company syndrome. We have dozens of VPs an...     10.0
# 286371  Mundane work. If you are not an engineer, you ...     10.0
# 286372  Little influence on which area you get assigne...     10.0
#
# [276431 rows x 9 columns]

# %% [markdown]
# #### 2. Pros, Cons, Headline:
#
#  Estas variables son textos de carácter cualitativo, pero para explotar su valor en nuestro modelo necesitamos poder transformarlas en un valor númerico. Para se utilizará a continuación un framework de Sentiment Analysis que permite convertir textos y sacar un rango de -1 a 1, siendo -1 expresiones de mucha negatividad y 1 expresiones muy positivas.

# %%
# %pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2023.11.17)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

sentiment_cols=['headline', 'cons', 'pros']

df_categorical_features.loc[:, sentiment_cols] = df_categorical_features.loc[:, sentiment_cols].applymap(lambda x: analyzer.polarity_scores(str(x)), na_action='ignore')

# %%
df_categorical_features.loc[:,sentiment_cols] = df_categorical_features.loc[:, sentiment_cols].applymap(lambda x: x['compound'], na_action='ignore' )

# %%
df_categorical_features
# Out:
#          firm date_review job_title current location headline    pros    cons  \
# 0         1.0  2015-04-05       NaN     1.0      NaN  -0.4767   0.861 -0.7351
# 1         1.0  2015-12-11   16243.0     3.0    805.0   0.1531  0.7184 -0.8663
# 2         1.0  2016-01-28   16243.0     2.0    805.0  -0.6808  0.4404  0.1709
# 3         1.0  2016-04-16       NaN     1.0      NaN   0.3612  0.4215 -0.6486
# 4         1.0  2016-04-23   16243.0     3.0    805.0      0.0  0.6908 -0.7861
# ...       ...         ...       ...     ...      ...      ...     ...     ...
# 286368  149.0  2009-05-06   23261.0     9.0   3821.0      0.0  0.9868  0.8621
# 286369  149.0  2009-05-10    1331.0     9.0      NaN   0.6249  0.4592  0.9253
# 286370  149.0  2009-05-10   23218.0     1.0   3821.0      0.0  0.9536 -0.2493
# 286371  149.0  2009-05-11    2880.0     1.0   3821.0   0.7845  0.9468   0.296
# 286372  149.0  2009-05-12   22395.0     9.0   3821.0   0.6597  0.9636     0.0
#
#        industry
# 0           5.0
# 1           5.0
# 2           5.0
# 3           5.0
# 4           5.0
# ...         ...
# 286368     10.0
# 286369     10.0
# 286370     10.0
# 286371     10.0
# 286372     10.0
#
# [276431 rows x 9 columns]

# %%
df_numerical_features[sentiment_cols]=df_categorical_features[sentiment_cols]

# %%
df_categorical_features = df_categorical_features.drop(labels=sentiment_cols, axis=1)

df_categorical_features=df_categorical_features.drop(labels='date_review', axis=1)

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

imputador_iter = IterativeImputer()
numerical_data = imputador_iter.fit_transform(df_numerical_features)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_iterative.py:785: ConvergenceWarning:
#
# [IterativeImputer] Early stopping criterion not reached.

# %%
numerical_df = pd.DataFrame(numerical_data, columns=df_numerical_features.columns)
numerical_df
# Out:
#         overall_rating  work_life_balance  culture_values  career_opp  \
# 0                  2.0                4.0        3.000000         2.0
# 1                  2.0                3.0        1.000000         2.0
# 2                  1.0                1.0        1.000000         1.0
# 3                  5.0                2.0        3.000000         2.0
# 4                  1.0                2.0        1.000000         2.0
# ...                ...                ...             ...         ...
# 276426             3.0                4.0        3.238677         2.0
# 276427             5.0                5.0        4.817994         5.0
# 276428             4.0                3.0        3.904095         3.0
# 276429             3.0                4.0        3.290660         2.0
# 276430             4.0                5.0        4.626527         2.0
#
#         comp_benefits  senior_mgmt  recommend  ceo_approv   outlook  headline  \
# 0                 3.0          3.0   1.000000    2.110797  2.000000   -0.4767
# 1                 1.0          4.0   1.000000    1.949635  2.000000    0.1531
# 2                 1.0          1.0   1.000000    1.472197  1.000000   -0.6808
# 3                 2.0          3.0   1.000000    2.173824  2.000000    0.3612
# 4                 1.0          1.0   1.000000    1.462793  1.000000    0.0000
# ...               ...          ...        ...         ...       ...       ...
# 276426            4.0          3.0   2.038636    2.000000  2.050951    0.0000
# 276427            5.0          5.0   3.000000    2.000000  2.746256    0.6249
# 276428            4.0          3.0   3.000000    3.000000  2.658773    0.0000
# 276429            3.0          2.0   2.291991    3.000000  2.331445    0.7845
# 276430            3.0          5.0   3.000000    3.000000  2.707644    0.6597
#
#           cons    pros
# 0      -0.7351  0.8610
# 1      -0.8663  0.7184
# 2       0.1709  0.4404
# 3      -0.6486  0.4215
# 4      -0.7861  0.6908
# ...        ...     ...
# 276426  0.8621  0.9868
# 276427  0.9253  0.4592
# 276428 -0.2493  0.9536
# 276429  0.2960  0.9468
# 276430  0.0000  0.9636
#
# [276431 rows x 12 columns]

# %%
for col in df_categorical_features.columns:
    df_categorical_features[col] = pd.to_numeric(df_categorical_features[col], errors='coerce')


log_df = np.log(df_categorical_features)

# %%
log_df
# Out:
#             firm  job_title   current  location  industry
# 0       0.000000        NaN  0.000000       NaN  1.609438
# 1       0.000000   9.695417  1.098612  6.690842  1.609438
# 2       0.000000   9.695417  0.693147  6.690842  1.609438
# 3       0.000000        NaN  0.000000       NaN  1.609438
# 4       0.000000   9.695417  1.098612  6.690842  1.609438
# ...          ...        ...       ...       ...       ...
# 286368  5.003946  10.054533  2.197225  8.248267  2.302585
# 286369  5.003946   7.193686  2.197225       NaN  2.302585
# 286370  5.003946  10.052683  0.000000  8.248267  2.302585
# 286371  5.003946   7.965546  0.000000  8.248267  2.302585
# 286372  5.003946  10.016593  2.197225  8.248267  2.302585
#
# [276431 rows x 5 columns]

# %%
categorical_data = imputador_iter.fit_transform (log_df)

categorical_df =  pd.DataFrame(categorical_data, columns = df_categorical_features.columns)

# %%
df_categorical_real= np.exp(categorical_df)

# %%
df_categorical_real
# Out:
#          firm     job_title  current     location  industry
# 0         1.0   6831.677953      1.0  2642.917170       5.0
# 1         1.0  16243.000000      3.0   805.000000       5.0
# 2         1.0  16243.000000      2.0   805.000000       5.0
# 3         1.0   6831.677953      1.0  2642.917170       5.0
# 4         1.0  16243.000000      3.0   805.000000       5.0
# ...       ...           ...      ...          ...       ...
# 276426  149.0  23261.000000      9.0  3821.000000      10.0
# 276427  149.0   1331.000000      9.0  2345.985056      10.0
# 276428  149.0  23218.000000      1.0  3821.000000      10.0
# 276429  149.0   2880.000000      1.0  3821.000000      10.0
# 276430  149.0  22395.000000      9.0  3821.000000      10.0
#
# [276431 rows x 5 columns]

# %%
df_categorical_features
# Out:
#          firm  job_title  current  location  industry
# 0         1.0        NaN      1.0       NaN       5.0
# 1         1.0    16243.0      3.0     805.0       5.0
# 2         1.0    16243.0      2.0     805.0       5.0
# 3         1.0        NaN      1.0       NaN       5.0
# 4         1.0    16243.0      3.0     805.0       5.0
# ...       ...        ...      ...       ...       ...
# 286368  149.0    23261.0      9.0    3821.0      10.0
# 286369  149.0     1331.0      9.0       NaN      10.0
# 286370  149.0    23218.0      1.0    3821.0      10.0
# 286371  149.0     2880.0      1.0    3821.0      10.0
# 286372  149.0    22395.0      9.0    3821.0      10.0
#
# [276431 rows x 5 columns]

# %%
df_categorical_real= df_categorical_real.apply(lambda x: round(x))

# %%
train_df = numerical_df.join(df_categorical_real)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276431 entries, 0 to 276430
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   overall_rating     276431 non-null  float64
#  1   work_life_balance  276431 non-null  float64
#  2   culture_values     276431 non-null  float64
#  3   career_opp         276431 non-null  float64
#  4   comp_benefits      276431 non-null  float64
#  5   senior_mgmt        276431 non-null  float64
#  6   recommend          276431 non-null  float64
#  7   ceo_approv         276431 non-null  float64
#  8   outlook            276431 non-null  float64
#  9   headline           276431 non-null  float64
#  10  cons               276431 non-null  float64
#  11  pros               276431 non-null  float64
#  12  firm               276431 non-null  float64
#  13  job_title          276431 non-null  float64
#  14  current            276431 non-null  float64
#  15  location           276431 non-null  float64
#  16  industry           276431 non-null  float64
# dtypes: float64(17)
# memory usage: 35.9 MB

# %%
train_df.head()
# Out:
#    overall_rating  work_life_balance  culture_values  career_opp  \
# 0             2.0                4.0             3.0         2.0
# 1             2.0                3.0             1.0         2.0
# 2             1.0                1.0             1.0         1.0
# 3             5.0                2.0             3.0         2.0
# 4             1.0                2.0             1.0         2.0
#
#    comp_benefits  senior_mgmt  recommend  ceo_approv  outlook  headline  \
# 0            3.0          3.0        1.0    2.110797      2.0   -0.4767
# 1            1.0          4.0        1.0    1.949635      2.0    0.1531
# 2            1.0          1.0        1.0    1.472197      1.0   -0.6808
# 3            2.0          3.0        1.0    2.173824      2.0    0.3612
# 4            1.0          1.0        1.0    1.462793      1.0    0.0000
#
#      cons    pros  firm  job_title  current  location  industry
# 0 -0.7351  0.8610   1.0     6832.0      1.0    2643.0       5.0
# 1 -0.8663  0.7184   1.0    16243.0      3.0     805.0       5.0
# 2  0.1709  0.4404   1.0    16243.0      2.0     805.0       5.0
# 3 -0.6486  0.4215   1.0     6832.0      1.0    2643.0       5.0
# 4 -0.7861  0.6908   1.0    16243.0      3.0     805.0       5.0

# %% [markdown]
# # 1. Conociendo nuestro dataset

# %% [markdown]
# ## 1.1 Cantidad de reseñas por empresa

# %%
df.value_counts('location').head(20)
# Out:
# location
# London, England, England        23561
# New York, NY                    14813
# Bangalore                        7234
# Gurgaon, Haryana, Haryana        4891
# Hyderābād                        4365
# Mumbai                           3876
# Singapore                        3446
# Pune                             2909
# Chicago, IL                      2709
# Toronto, ON                      2338
# Manchester, England, England     2200
# San Francisco, CA                1970
# Chennai                          1835
# Los Angeles, CA                  1800
# Cupertino, CA                    1734
# Dublin, Dublin                   1710
# Dallas, TX                       1689
# Sydney                           1654
# Boston, MA                       1594
# Atlanta, GA                      1534
# dtype: int64

# %% [markdown]
# ### 3. Compañias y Cargos:
#
# Estas variables no son transformables pero son las vairables cualitativas nominales que son muy interesantes para contextualizar los resultado de nuestro analisís.

# %%
firms = df[['firm', 'job_title']]
firms.describe()
print((firms['job_title'].value_counts())/df.shape[0]*100)
# Out:
# Anonymous Employee                        19.243811
# Consultant                                 2.707373
# Manager                                    2.303341
# Senior Consultant                          2.131988
# Analyst                                    1.999596
#                                             ...
# Charles River Analyst                      0.000361
# Infrastructure Technician (Middleware)     0.000361
# CHANGE ASSURANCE                           0.000361
# OTC Clearing/Prime Brokerage               0.000361
# Ad Sense Sales Manager                     0.000361
# Name: job_title, Length: 26786, dtype: float64

# %% [markdown]
# > Podemos observar que un 19% de los reviews son anónimos y un 9.5% están vacios. En este caso es válido simplemente agregarlos a la categoría de anónimo que básicamente corresponde con la misma clasificación. Dejando los anónimos  como un 31% apróximadamente. Por la naturaleza de los reviews de Glassdoor tiene sentido que haya muchas reviews que se nieguen a poner el rol y la empresa.

# %%
print((firms['firm'].value_counts())/df.shape[0]*100)

(firms['firm'].value_counts()/df.shape[0]*100)
# Out:
# Deloitte                                              15.479102
# EY                                                    11.622043
# Apple                                                  7.325960
# Citi                                                   6.496613
# Barclays                                               3.502810
#                                                         ...
# Animal-and-Plant-Health-Agency                         0.007936
# BayWa-r-e-renewable-energy                             0.006493
# Engineering-and-Physical-Sciences-Research-Council     0.006133
# Abertawe-Bro-Morgannwg-University-Health-Board         0.003247
# Achieving-for-Children                                 0.002164
# Name: firm, Length: 149, dtype: float64
# Deloitte                                              15.479102
# EY                                                    11.622043
# Apple                                                  7.325960
# Citi                                                   6.496613
# Barclays                                               3.502810
#                                                         ...
# Animal-and-Plant-Health-Agency                         0.007936
# BayWa-r-e-renewable-energy                             0.006493
# Engineering-and-Physical-Sciences-Research-Council     0.006133
# Abertawe-Bro-Morgannwg-University-Health-Board         0.003247
# Achieving-for-Children                                 0.002164
# Name: firm, Length: 149, dtype: float64

# %% [markdown]
# >De la misma forma podemos observar que hay una representación muy grande en la muestra de pocas empresas, siendo estas Delloite (16.4%), Ernest & Young (12%), Apple (7%), Citi Bank (6,5%) y la entidad financiera Barclay's (3.39%). Con casi el 40% de los reviews. Sería interesante estudiar el dataset filtrando estas empresas a ver que tan distinto llegan a ser los resultados.

# %% [markdown]
# > No hay una diferencia muy significativa entre los dos tipos de promedio y como demuestra el gráfico el puntaje de la mayoría de las empresas estan concentradas alrededor del 3,5-3,6. Hay tres empresas que tienen puntuaciones muy por debajo del promedio.

# %%
    toptenfirms = firms['firm'].value_counts().head(10)

    fig, ax = plt.subplots(figsize =(40,30))




    review_quantity = toptenfirms.values
    firm_names = toptenfirms.index

    ax.barh(firm_names, review_quantity)
    # Remove axes splines
    for s in ['top', 'bottom', 'left', 'right']:
        ax.spines[s].set_visible(False)

    # Remove x, y Ticks
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')

    # Add padding between axes and labels
    ax.xaxis.set_tick_params(pad = 5)
    ax.yaxis.set_tick_params(pad = 5)

    # Add x, y gridlines
    ax.grid( color ='grey',
            linestyle ='-.', linewidth = 0.5,
            alpha = 1)

    # Show top values
    ax.invert_yaxis()

    # Add annotation to bars
    for i in ax.patches:
        plt.text(i.get_width()+0.6, i.get_y()+0.9,
                str(round((i.get_width()), 2)),
                fontsize = 10, fontweight ='bold',
                color ='grey')

    # Add Plot Title
    ax.set_title('Opiniones por empresa',
                loc ='right', )



    # Show Plot
    # plt.show()
# Out:
# Text(1.0, 1.0, 'Opiniones por empresa')

# %%
#Filtramos los resultados por pertenencia a estas compañias

Not_DEACB_firms = df[~df['firm'].isin(['Deloitte','EY','Apple','Citi','Barclays'])]

DEACB_firms = df[df['firm'].isin(['Deloitte','EY','Apple','Citi','Barclays'])]

# %%
print((Not_DEACB_firms['firm'].value_counts())/df.shape[0]*100)
# Out:
# American-Express                                      3.306927
# Goldman-Sachs                                         3.122227
# BNY-Mellon                                            2.391723
# Deutsche-Bank                                         2.264020
# GlaxoSmithKline                                       1.986609
#                                                         ...
# Animal-and-Plant-Health-Agency                        0.007936
# BayWa-r-e-renewable-energy                            0.006493
# Engineering-and-Physical-Sciences-Research-Council    0.006133
# Abertawe-Bro-Morgannwg-University-Health-Board        0.003247
# Achieving-for-Children                                0.002164
# Name: firm, Length: 144, dtype: float64

# %%
# no sé porque
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
@interact

def countplots(
    column = list(df.select_dtypes('number').columns)
):
    fig, axs = plt.subplots(ncols=3, sharey= True)

    fig.suptitle(f'Distribución de {column}')
    sns.countplot(data=DEACB_firms, x=column,
        palette="pastel", edgecolor=".6", ax=axs[0])
    axs[0].set_title('Firmas del Top 10')
    sns.countplot(data=Not_DEACB_firms, x=column,
        palette="pastel", edgecolor=".6", ax=axs[1])
    axs[1].set_title('Resto de compañias')
    sns.countplot(data=df, x=column,
        palette="pastel", edgecolor=".6", ax=axs[2])
    axs[2].set_title('Todas las compañias')

    plt.show()
# Out:
# interactive(children=(Dropdown(description='column', options=('overall_rating', 'work_life_balance', 'culture_…

# %% [markdown]
# > El top diez de  las compañias por cantidad de reseñas tiene una menor menos puntuaciones de 1 ó 2 pero parece tener una distribución de estas reseñas que sigue la tendencia del resto de las compañias de la muestra. La tendencia demuestra una concentración de reseñas con valores superiores a tres en los tres escenarios. Y tambin tanto para las empresas más reseñadas y el resto el valor que más ponen en sus reseñas es 4.
#
# > Sin embargo, cuando nos movemos a las variables de oportunidad de crecimieto o

# %% [markdown]
# ## 1.2 Cantidad de reseñas por industria

# %% [markdown]
# ####  Industria
#
# Esta variable fue generada manualmente, con información de LinkedIn sobre las compañias o sus páginas web. El número de categorías fue reducido en la medida de lo posible. Hay varias empresas cuyo sector era demasido nicho, como por ejemplo Christies que es la compañia más grande de objetos y arte de lujo en el mundo (junto a Sotheby's), que se colocó en una categoría llamada "Otro" para destilar un poco información. Del mismo modo hay compañias de desarrollo de software, SaS Y desarrollo de tecnología  que se juntaron en la categoría de IT. El objetivo es que las categorías tengan mamyor poder explicativo:

# %%
industries['industry'].value_counts()
# Out:
# Finance               26
# Retail                15
# Consulting            15
# Healthcare            14
# Govertment            11
# IT                    11
# Other                  9
# Hospitality            7
# Education              7
# Engineering            6
# Pharmaceutical         5
# Real Estate            5
# Energy/Utillities      5
# Legal Services         5
# Senior Care            4
# Logistics              3
# Food and Beverages     1
# Name: industry, dtype: int64

# %%
industries.loc[ industries['industry']=='Logistics'].head()
# Out:
#                  firm   industry  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 67    British-Airways  Logistics         NaN         NaN         NaN
# 115  DHL-Supply-Chain  Logistics         NaN         NaN         NaN
# 120          DPDgroup  Logistics         NaN         NaN         NaN
#
#     Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8
# 67         NaN         NaN         NaN         NaN
# 115        NaN         NaN         NaN         NaN
# 120        NaN         NaN         NaN         NaN

# %%
overall_mean = df.groupby(['firm','industry'],as_index=False)['overall_rating'].agg(['mean','count']).reset_index()

print(overall_mean)

fig = px.scatter(overall_mean , x='mean',y='count', color='industry', log_y= True,
  hover_name='firm', labels={'mean': "overall rating", 'count':'number of reviews'}, size= 'mean',
  title='Puntaje Total Promedio por Compañia')


fig.show()

print('promedio de todos los reviews:' + str(df['overall_rating'].mean())+ '|' + 'promedio no pesado:'+ str(overall_mean['mean'].mean()))
# Out:
#                       firm        industry      mean  count
# 0    AFH-Wealth-Management         Finance  2.904762     63
# 1                  AJ-Bell         Finance  3.359649    114
# 2                     ALDI          Retail  3.422127    931
# 3                      AQA       Education  3.622807    114
# 4                     ASDA          Retail  3.352010   4676
# ..                     ...             ...       ...    ...
# 144                Gateley  Legal Services  4.525424     59
# 145               Gi-Group      Consulting  3.392857    196
# 146        GlaxoSmithKline  Pharmaceutical  3.702560   5507
# 147          Goldman-Sachs         Finance  3.847487   8655
# 148                 Google              IT  4.018018    222
#
# [149 rows x 4 columns]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="600d7911-34d4-44f5-825a-a13eb48f9944" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("600d7911-34d4-44f5-825a-a13eb48f9944")) {                    Plotly.newPlot(                        "600d7911-34d4-44f5-825a-a13eb48f9944",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eindustry=Finance\u003cbr\u003eoverall rating=%{marker.size}\u003cbr\u003enumber of reviews=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["AFH-Wealth-Management","AJ-Bell","AXA-UK","AlixPartners","American-Express","Aon","Aviva","BNP-Paribas","BNY-Mellon","Barclays","Barnett-Waddingham","Bloomberg-L-P","Blue-Arrow","Blue-Yonder","Brewin-Dolphin","Bupa","Capita","Capital-Group","Citi","Covea-Insurance","Curtis-Banks","Deutsche-Bank","Diligenta","EBRD","Equiniti","Goldman-Sachs"],"legendgroup":"Finance","marker":{"color":"#636efa","size":[2.9047619047619047,3.3596491228070176,4.015503875968992,4.211538461538462,3.8622231918839316,3.4754716981132074,3.466108786610879,3.5056756756756755,3.119607843137255,3.5840370751802264,4.271428571428571,3.6044606281292673,3.580508474576271,3.778794402583423,3.752,3.3552123552123554,2.8798479087452473,3.654212454212454,3.4797045921483702,4.219178082191781,2.425925925925926,3.4561822817080943,2.3636363636363638,3.3961661341853033,3.03125,3.847487001733102],"sizemode":"area","sizeref":0.011627906976744186,"symbol":"circle"},"mode":"markers","name":"Finance","orientation":"v","showlegend":true,"x":[2.9047619047619047,3.3596491228070176,4.015503875968992,4.211538461538462,3.8622231918839316,3.4754716981132074,3.466108786610879,3.5056756756756755,3.119607843137255,3.5840370751802264,4.271428571428571,3.6044606281292673,3.580508474576271,3.778794402583423,3.752,3.3552123552123554,2.8798479087452473,3.654212454212454,3.4797045921483702,4.219178082191781,2.425925925925926,3.4561822817080943,2.3636363636363638,3.3961661341853033,3.03125,3.847487001733102],"xaxis":"x","y":[63,114,258,52,9167,3975,1195,3700,6630,9710,70,4394,236,1858,125,518,3945,1365,18009,73,54,6276,165,313,256,8655],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eindustry=Retail\u003cbr\u003eoverall rating=%{marker.size}\u003cbr\u003enumber of reviews=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["ALDI","ASDA","ASOS","Arcadia","Arnold-Clark","B-and-M-Retail","B-and-Q","Boots","Burberry","CarShop-UK","Co-op","DFS-Furniture","Debenhams","Diageo","Dixons-Carphone"],"legendgroup":"Retail","marker":{"color":"#EF553B","size":[3.422126745435016,3.352010265183918,3.2472283813747227,3.0030165912518854,3.401174168297456,3.513719512195122,3.3197231833910035,3.4504377294549564,3.4630454140694567,4.651162790697675,3.4658077304261643,3.3642384105960264,3.0816890292028414,3.774267662263067,3.0834752981260647],"sizemode":"area","sizeref":0.011627906976744186,"symbol":"circle"},"mode":"markers","name":"Retail","orientation":"v","showlegend":true,"x":[3.422126745435016,3.352010265183918,3.2472283813747227,3.0030165912518854,3.401174168297456,3.513719512195122,3.3197231833910035,3.4504377294549564,3.4630454140694567,4.651162790697675,3.4658077304261643,3.3642384105960264,3.0816890292028414,3.774267662263067,3.0834752981260647],"xaxis":"x","y":[931,4676,902,663,511,1312,1445,3541,1123,258,2018,151,2534,1741,2935],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eindustry=Education\u003cbr\u003eoverall rating=%{marker.size}\u003cbr\u003enumber of reviews=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["AQA","BPP-Holdings","Birkbeck-College" ...
# promedio de todos los reviews:3.636645671450113|promedio no pesado:3.5491963077444213

# %% [markdown]
# ## 1.3 Cantidad de reseñas por Localización

# %%
df.value_counts('location')
# Out:
# location
# London, England, England      23561
# New York, NY                  14813
# Bangalore                      7234
# Gurgaon, Haryana, Haryana      4891
# Hyderābād                      4365
#                               ...
# Nibong Tebal                      1
# Envira, Amazonas, Amazonas        1
# Enterprise, AL                    1
# Nieborowice                       1
# ‘Asamah                           1
# Length: 6386, dtype: int64

# %%
porce_resenas = df.value_counts('location')

# %%
porce_resenas.keys()

porce_resenas = porce_resenas.loc[porce_resenas.values > 1000]

# %%
porce_resenas = porce_resenas/df.shape[0]*100

# %%
porce_resenas.sum()
# Out:
# 36.27807478914597

# %%
 data = porce_resenas
# Create a bar chart with angled x-axis labels
fig = px.bar(x=data.index, y=data.values, labels={'x': 'Ciudad', 'y': 'Num. Reseñas'})

# Set the angle for x-axis labels
fig.update_layout(xaxis=dict(tickangle=-45),
                  title='Distribucion de Reseñas por ciudad')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f4feb604-a020-4676-899a-59a82e8ee71f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4feb604-a020-4676-899a-59a82e8ee71f")) {                    Plotly.newPlot(                        "f4feb604-a020-4676-899a-59a82e8ee71f",                        [{"alignmentgroup":"True","hovertemplate":"Ciudad=%{x}\u003cbr\u003eNum. Rese\u00f1as=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["London, England, England","New York, NY","Bangalore","Gurgaon, Haryana, Haryana","Hyder\u0101b\u0101d","Mumbai","Singapore","Pune","Chicago, IL","Toronto, ON","Manchester, England, England","San Francisco, CA","Chennai","Los Angeles, CA","Cupertino, CA","Dublin, Dublin","Dallas, TX","Sydney","Boston, MA","Atlanta, GA","Hong Kong","Washington, DC","Birmingham, England, England","Phoenix, AZ","New Delhi","Glasgow, Scotland, Scotland","Amsterdam","Leeds, England, England","Houston, TX","Kuala Lumpur"],"xaxis":"x","y":[8.499455278745769,5.343679429738173,2.6096116245680108,1.764391824130791,1.5746412415315687,1.3982381333737364,1.2431188358116347,1.0494000851352425,0.9772515746412416,0.84341608767487,0.7936336154340093,0.7106628283659083,0.6619625837824579,0.6493365944460077,0.6255275859829874,0.6168697647237072,0.6092941711218371,0.596668181785387,0.5750236286371868,0.5533790754889866,0.5364241755228963,0.506843286220356,0.46896531821100557,0.4621112097140755,0.4613897246091354,0.4570608139794954,0.4447955671955152,0.4220687863899049,0.41413245023556483,0.40872131194851485],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0. ...

# %% [markdown]
# En el gráfico están representadas todas las ciudades con más de 1000 personas con mucha representación de ciudades estadounidenses. Pero este total representa apenas el 36.2% de todas las reseñas por lo que la muestra representa una diversidad de ciudades de todo el mundo. De una muestra de 277206 personas 14 % por ciento son de Londres y New York, siendo Londres la ciudad con el mayor número de reseñas (8,5%)

# %% [markdown]
# # Variable Target: Overall_Rating
#
# La variable objetivo es de tipo númerica, así que podemos utilizar un modelo de tipo Aprendizaje supervisado y algoritmos de Regresión.
#
# Se explorarán en consiguiente el comportamiento de la variable con algunos analisis estadísticos.

# %%
target_variable = df['overall_rating']

target_variable.describe().round(2)
# Out:
# count    277206.00
# mean          3.64
# std           1.18
# min           1.00
# 25%           3.00
# 50%           4.00
# 75%           5.00
# max           5.00
# Name: overall_rating, dtype: float64

# %%
#Distribución de variable target
media = target_variable.mean()
mediana = target_variable.median()
primer_cuartil = target_variable.quantile(0.25)
tercer_cuartil = target_variable.quantile(0.75)

print(media)
plt.figure()
# Histograma
sns.histplot(data = df,
             x = 'overall_rating',
             bins = 5,
             alpha = 0.25,
             discrete= True,
             kde = True,
             kde_kws = dict(
                 bw_adjust=9
             ),
             stat='probability')
# Agrego linea de promedio
plt.axvline(x = media,
            color = 'red',
            linestyle = '-',
            label = 'Promedio',
            linewidth = 3)
# Agrego linea de mediana
plt.axvline(x = mediana,
            color = '#11B613',
            linestyle = '-',
            label = 'Mediana',
            linewidth = 3)
# Agrego linea de primer cuartil
plt.axvline(x = primer_cuartil,
            color = 'black',
            linestyle = '--',
            label = 'Primer Cuartil',
            linewidth = 2)
# Agrego linea de tercer cuartil
plt.axvline(x = tercer_cuartil,
            color = 'black',
            linestyle = '--',
            label = 'Tercer Cuartil',
            linewidth = 2)

plt.legend()

plt.title('Distribución de Overall_Rating')
# Out:
# 3.636645671450113
# Text(0.5, 1.0, 'Distribución de Overall_Rating')

# %% [markdown]
# ## Analisis de  variable Target: Overall_Rating
#
# La variable objetivo sigue una distribución asimetrica neativa (la mediana es mayor que el promedio), concentrando una porción importante en reseñas con valores altos, y se observan pocos valores bajos.
#
# Para este tipo de distibuciones, es apropiado utilizar una técnica de normalización que permita preparar nuestra data para otro tipo de análisis.
#
# Se preesentará a continuación la distribución con

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

targetVarNorm = target_variable.values.reshape(-1, 1)

min_max_scaler = MinMaxScaler()

print(targetVarNorm)
X_train_minmax = min_max_scaler.fit_transform(targetVarNorm)


scaler = StandardScaler()
zscores = scaler.fit_transform(targetVarNorm)

logRatings = np.log(targetVarNorm)

fig, axs = plt.subplots(ncols=3, sharey= True)

sns.histplot(data = X_train_minmax,

             alpha = 0.1,
             kde = True,
             bins=10,
             stat='probability',
             color = '#B76BCB',
             kde_kws = dict(
                 bw_adjust=9
             ),
             ax=axs[0]
)
axs[0].set_title('Max-Min')

sns.histplot(data = zscores,
             alpha = 0.1,
             kde = True,
             bins=10,
             stat='probability',
             color = '#B76BCB',
             kde_kws = dict(
                 bw_adjust=9
             ),
             ax=axs[1]
)
axs[1].set_title('Z-Scores')

sns.histplot(data = logRatings,


             alpha = 0.1,
             kde = True,
             bins=10,
             stat='probability',
             color = '#B76BCB',
             kde_kws = dict(
                 bw_adjust=9
             ),
             ax=axs[2]
)
axs[2].set_title('Log')
# Out:
# [[2]
#  [2]
#  [1]
#  ...
#  [3]
#  [4]
#  [5]]
# Text(0.5, 1.0, 'Log')

# %%
target_variable.unique()
# Out:
# array([2, 1, 5, 3, 4])

# %%
df['overall_rating'].unique()
# Out:
# array([2, 1, 5, 3, 4])

# %% [markdown]
# ## Conclusión:
# El proceso de normalizacion no ha cambiado mucho la distribución pero en variables con un rango tan pequeño de valores discretos es de esperarse.

# %% [markdown]
# ### Correlacion

# %%
X = train_df
correlation_matrix = X.corr()
fig, ax = plt.subplots(figsize =(15,10))

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
corr_overall_rating = correlation_matrix['overall_rating'].reset_index().sort_values('overall_rating')
fig = go.Figure()


fig.add_trace(go.Bar(
            x=corr_overall_rating['overall_rating'],
            y=corr_overall_rating['index'],
            orientation='h',
            name='Correlacion con overall_rating'
            ))
fig.update_layout(barmode='overlay', xaxis_title='correlación',
                  title='Correlaciones de features con Overall_Rating')


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="82f9a745-a5a6-44a9-bb1c-501e8511af30" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82f9a745-a5a6-44a9-bb1c-501e8511af30")) {                    Plotly.newPlot(                        "82f9a745-a5a6-44a9-bb1c-501e8511af30",                        [{"name":"Correlacion con overall_rating","orientation":"h","x":[-0.14520391096037802,-0.06727521679874647,-0.01783089419134277,0.005840434042338807,0.009867382849047495,0.19972226510240665,0.24510648435693774,0.4569653641805383,0.5790510010933575,0.6307216414709194,0.6327405902385888,0.6883075922481859,0.7434656772246335,0.7711115084557504,0.7808785355414978,0.7997384689600721,1.0],"y":["current","industry","location","firm","job_title","cons","pros","headline","work_life_balance","ceo_approv","comp_benefits","outlook","career_opp","recommend","senior_mgmt","culture_values","overall_rating"],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5 ...

# %%
high_corr_imp = X[['overall_rating','culture_values','senior_mgmt','recommend','career_opp','work_life_balance' ,'outlook','comp_benefits','firm']]
high_corr = df[['overall_rating','culture_values','senior_mgmt','recommend','career_opp','work_life_balance' , 'outlook','firm','comp_benefits']]

# %%
high_corr_df = high_corr.drop('firm', axis=1)

# %%
high_corr_df
# Out:
#         overall_rating  culture_values  senior_mgmt  recommend  career_opp  \
# 0                    2             3.0          3.0        1.0         2.0
# 1                    2             1.0          4.0        1.0         2.0
# 2                    1             1.0          1.0        1.0         1.0
# 3                    5             3.0          3.0        1.0         2.0
# 4                    1             1.0          1.0        1.0         2.0
# ...                ...             ...          ...        ...         ...
# 286369               5             NaN          5.0        3.0         5.0
# 286370               4             NaN          3.0        3.0         3.0
# 286371               3             NaN          2.0        NaN         2.0
# 286372               4             NaN          5.0        3.0         2.0
# 286373               5             NaN          4.0        3.0         4.0
#
#         work_life_balance  outlook  comp_benefits
# 0                     4.0      2.0            3.0
# 1                     3.0      2.0            1.0
# 2                     1.0      1.0            1.0
# 3                     2.0      2.0            2.0
# 4                     2.0      1.0            1.0
# ...                   ...      ...            ...
# 286369                5.0      NaN            5.0
# 286370                3.0      NaN            4.0
# 286371                4.0      NaN            3.0
# 286372                5.0      NaN            3.0
# 286373                5.0      NaN            4.0
#
# [277206 rows x 8 columns]

# %%
high_corr_df.hist(bins=15, color='#0CAA41', edgecolor='#021B0A', linewidth=1.0,
           xlabelsize=8, ylabelsize=8, grid=False, sharey=True)
plt.tight_layout(rect=(0, 0, 2, 2))

# %%
f, axs = plt.subplots(3, 3, figsize=(20,15))
f.suptitle('Distribución ', fontsize=14)

cols = high_corr_df.columns
i=0
j=0
items=0
for col in cols:


  sns.boxplot(x=f"{col}", y="overall_rating", data=high_corr_df, ax=axs[i,j])
  ax.set_xlabel(f"{col}",size = 12,alpha=0.8)
  ax.set_ylabel("Overall Rating",size = 12,alpha=0.8)
  j= j+1
  items= items+1
  if items >= 3:
    i=i+1
    items=0
    j=0

# %%
top_ten = overall_mean.sort_values(by='mean', ascending=False).head(10)

top_worst = overall_mean.sort_values(by='mean').head(10)

# %%
pond_overall_rating = overall_mean
pond_overall_rating['mean_weighted']= overall_mean['mean']*overall_mean['count']/overall_mean['count'].sum()

# %%
top_worst_weighted = pond_overall_rating.sort_values(by='mean_weighted').head(10)

top_ten_weighted = pond_overall_rating.sort_values(by='mean_weighted', ascending=False).head(10)

# %%
overall_means = df.groupby(['firm','industry'],as_index=False)['overall_rating','culture_values','senior_mgmt','recommend','career_opp', 'outlook'].agg(['mean','count']).reset_index()

# %%
overall_means
# Out:
#                       firm        industry overall_rating        \
#                                                      mean count
# 0    AFH-Wealth-Management         Finance       2.904762    63
# 1                  AJ-Bell         Finance       3.359649   114
# 2                     ALDI          Retail       3.422127   931
# 3                      AQA       Education       3.622807   114
# 4                     ASDA          Retail       3.352010  4676
# ..                     ...             ...            ...   ...
# 144                Gateley  Legal Services       4.525424    59
# 145               Gi-Group      Consulting       3.392857   196
# 146        GlaxoSmithKline  Pharmaceutical       3.702560  5507
# 147          Goldman-Sachs         Finance       3.847487  8655
# 148                 Google              IT       4.018018   222
#
#     culture_values       senior_mgmt       recommend       career_opp        \
#               mean count        mean count      mean count       mean count
# 0         2.964912    57    2.807018    57  1.925926    54   2.872727    55
# 1         3.514286   105    3.142857   105  2.168317   101   3.304762   105
# 2         3.115723   795    2.998742   795  2.122085   729   3.198254   802
# 3         3.425532    94    2.882979    94  2.438202    89   2.723404    94
# 4         3.181668  3633    2.751163  3653  2.167421  3315   2.911557  3686
# ..             ...   ...         ...   ...       ...   ...        ...   ...
# 144       4.596154    52    4.423077    52  2.882353    51   4.285714    49
# 145       3.224852   169    3.060241   166  2.223684   152   3.076471   170
# 146       3.655172  4350    3.075610  4629  2.454761  4222   3.305842  4656
# 147       3.716617  6066    3.453915  6781  2.526769  5921   3.841644  6839
# 148            NaN     0    3.594595   222  2.868132   182   3.301802   222
#
#       outlook
#          mean count
# 0    2.285714    49
# 1    2.371134    97
# 2    2.383966   711
# 3    2.268293    82
# 4    2.097646  3144
# ..        ...   ...
# 144  2.869565    46
# 145  2.223776   143
# 146  2.286351  3817
# 147  2.511679  5052
# 148       NaN     0
#
# [149 rows x 14 columns]

# %%
top_ten_weighted
# Out:
#                  firm        industry      mean  count  mean_weighted
# 114          Deloitte      Consulting  3.779091  42909       0.584969
# 127                EY      Consulting  3.733309  32217       0.433887
# 24              Apple              IT  4.048257  20308       0.296574
# 85               Citi         Finance  3.479705  18009       0.226063
# 17   American-Express         Finance  3.862223   9167       0.127721
# 47           Barclays         Finance  3.584037   9710       0.125542
# 147     Goldman-Sachs         Finance  3.847487   8655       0.120127
# 117     Deutsche-Bank         Finance  3.456182   6276       0.078249
# 37         BNY-Mellon         Finance  3.119608   6630       0.074612
# 146   GlaxoSmithKline  Pharmaceutical  3.702560   5507       0.073555

# %%
x_10th_percentile = overall_means['overall_rating', 'mean'].quantile(0.1)
y_90th_percentile = overall_means['overall_rating', 'count'].quantile(0.2)
print(x_10th_percentile,y_90th_percentile)
selected_rows = overall_means[(overall_means['overall_rating', 'mean'] <= x_10th_percentile) & (overall_means['overall_rating', 'count'] >= y_90th_percentile)]
print("Selected Rows:")
selected_rows
# Out:
# 3.0613322161709258 103.60000000000002
# Selected Rows:
#                          firm    industry overall_rating       culture_values  \
#                                                     mean count           mean
# 19            Angard-Staffing  Consulting       2.788991   109       2.500000
# 25                    Arcadia      Retail       3.003017   663       2.774621
# 42             Babylon-Health  Healthcare       3.044811   424       3.055703
# 46      Barchester-Healthcare  Healthcare       2.879213   356       2.918495
# 48                 Barnardo-s       Other       3.046921   341       3.229965
# 65            Boots-Opticians  Healthcare       3.012945   309       2.869403
# 77                     Capita     Finance       2.879848  3945       2.735894
# 99           Creative-Support       Other       2.257778   225       2.472081
# 119                 Diligenta     Finance       2.363636   165       2.195652
# 131                  Equiniti     Finance       3.031250   256       2.991597
# 139  Four-Seasons-Health-Care  Healthcare       2.960366   328       2.901695
#
#           senior_mgmt       recommend       career_opp         outlook
#     count        mean count      mean count       mean count      mean count
# 19     78    2.506494    77  1.902439    82   1.860759    79  1.782609    69
# 25    528    2.638577   534  1.926148   501   2.601490   537  1.725610   492
# 42    377    2.568733   371  2.010870   368   2.920000   375  2.089674   368
# 46    319    2.668770   317  1.881250   320   2.990596   319  2.003300   303
# 48    287    2.489362   282  1.969697   264   2.650685   292  1.920635   252
# 65    268    2.405904   271  1.848485   231   2.727941   272  1.894737   228
# 77   3385    2.521230  3415  1.887662  3080   2.656431  3452  2.015326  2871
# 99    197    2.139175   194  1.543590   195   2.296482   199  1.661111   180
# 119   138    2.072464   138  1.535433   127   1.920290   138  1.717949   117
# 131   238    2.789030   237  2.054054   222   2.812500   240  2.145540   213
# 139   295    2.671233   292  1.903448   290   2.897959   294  1.940959   271

# %%
top_ten
# Out:
#                                                   firm           industry  \
# 79                                          CarShop-UK             Retail
# 43                                    Bain-and-Company         Consulting
# 144                                            Gateley     Legal Services
# 20                                       Anglian-Water  Energy/Utillities
# 87                                           CityFibre                 IT
# 7                                                Abcam         Healthcare
# 11                              Achieving-for-Children              Other
# 66                             Boston-Consulting-Group         Consulting
# 130  Engineering-and-Physical-Sciences-Research-Cou...        Govertment
# 12                                         ActionCOACH        Senior Care
#
#          mean  count
# 79   4.651163    258
# 43   4.559757   3623
# 144  4.525424     59
# 20   4.468635    271
# 87   4.441558     77
# 7    4.406897    145
# 11   4.333333      6
# 66   4.301789   3466
# 130  4.294118     17
# 12   4.283333     60

# %%
top_ten_weighted
# Out:
#                  firm        industry      mean  count  mean_weighted
# 114          Deloitte      Consulting  3.779091  42909       0.584969
# 127                EY      Consulting  3.733309  32217       0.433887
# 24              Apple              IT  4.048257  20308       0.296574
# 85               Citi         Finance  3.479705  18009       0.226063
# 17   American-Express         Finance  3.862223   9167       0.127721
# 47           Barclays         Finance  3.584037   9710       0.125542
# 147     Goldman-Sachs         Finance  3.847487   8655       0.120127
# 117     Deutsche-Bank         Finance  3.456182   6276       0.078249
# 37         BNY-Mellon         Finance  3.119608   6630       0.074612
# 146   GlaxoSmithKline  Pharmaceutical  3.702560   5507       0.073555

# %%
top_worst_weighted
# Out:
#                                                   firm           industry  \
# 11                              Achieving-for-Children              Other
# 8       Abertawe-Bro-Morgannwg-University-Health-Board         Healthcare
# 53                          BayWa-r-e-renewable-energy  Energy/Utillities
# 130  Engineering-and-Physical-Sciences-Research-Cou...        Govertment
# 22                      Animal-and-Plant-Health-Agency        Govertment
# 93                                     Companies-House        Govertment
# 90                                    Colosseum-Dental         Healthcare
# 49           Barnet-and-Chase-Farm-Hospitals-NHS-Trust         Healthcare
# 125                                    ENABLE-Scotland              Other
# 56             Betsi-Cadwaladr-University-Health-Board         Healthcare
#
#          mean  count  mean_weighted
# 11   4.333333      6       0.000094
# 8    3.333333      9       0.000108
# 53   3.833333     18       0.000249
# 130  4.294118     17       0.000263
# 22   3.681818     22       0.000292
# 93   4.086957     23       0.000339
# 90   2.916667     36       0.000379
# 49   3.785714     28       0.000382
# 125  2.761905     42       0.000418
# 56   3.076923     39       0.000433

# %%
top_worst
# Out:
#                          firm    industry      mean  count
# 99           Creative-Support       Other  2.257778    225
# 119                 Diligenta     Finance  2.363636    165
# 103              Curtis-Banks     Finance  2.425926     54
# 125           ENABLE-Scotland       Other  2.761905     42
# 19            Angard-Staffing  Consulting  2.788991    109
# 46      Barchester-Healthcare  Healthcare  2.879213    356
# 77                     Capita     Finance  2.879848   3945
# 0       AFH-Wealth-Management     Finance  2.904762     63
# 90           Colosseum-Dental  Healthcare  2.916667     36
# 139  Four-Seasons-Health-Care  Healthcare  2.960366    328

# %%
top_ten = overall_means.sort_values(by=[('overall_rating','mean')], ascending=False).head(10)

top_worst = overall_means.sort_values(by=[('overall_rating','mean')]).head(10)

# %%
top_worst
# Out:
#                          firm    industry overall_rating       culture_values  \
#                                                     mean count           mean
# 99           Creative-Support       Other       2.257778   225       2.472081
# 119                 Diligenta     Finance       2.363636   165       2.195652
# 103              Curtis-Banks     Finance       2.425926    54       2.489796
# 125           ENABLE-Scotland       Other       2.761905    42       2.558824
# 19            Angard-Staffing  Consulting       2.788991   109       2.500000
# 46      Barchester-Healthcare  Healthcare       2.879213   356       2.918495
# 77                     Capita     Finance       2.879848  3945       2.735894
# 0       AFH-Wealth-Management     Finance       2.904762    63       2.964912
# 90           Colosseum-Dental  Healthcare       2.916667    36       2.852941
# 139  Four-Seasons-Health-Care  Healthcare       2.960366   328       2.901695
#
#           senior_mgmt       recommend       career_opp         outlook
#     count        mean count      mean count       mean count      mean count
# 99    197    2.139175   194  1.543590   195   2.296482   199  1.661111   180
# 119   138    2.072464   138  1.535433   127   1.920290   138  1.717949   117
# 103    49    2.265306    49  1.622222    45   2.326531    49  1.840909    44
# 125    34    2.205882    34  1.687500    32   2.388889    36  1.928571    28
# 19     78    2.506494    77  1.902439    82   1.860759    79  1.782609    69
# 46    319    2.668770   317  1.881250   320   2.990596   319  2.003300   303
# 77   3385    2.521230  3415  1.887662  3080   2.656431  3452  2.015326  2871
# 0      57    2.807018    57  1.925926    54   2.872727    55  2.285714    49
# 90     34    2.823529    34  1.937500    32   2.823529    34  2.033333    30
# 139   295    2.671233   292  1.903448   290   2.897959   294  1.940959   271

# %%
categorias = ['overall_rating','culture_values','senior_mgmt','recommend','career_opp', 'outlook']

# %%
mean_of_top_tens = top_ten['overall_rating', 'mean'].mean()

mean_of_top10_w = top_ten_weighted['mean'].mean()

mean_of_top_worst = top_worst['overall_rating', 'mean'].mean()

mean_of_top_worst_w =top_worst_weighted['mean'].mean()

print(f'promedio de empresas top 10 : {mean_of_top_tens} \
promedio de empresas top 10 ponderadas: {mean_of_top10_w}\
promedio peores 10: {mean_of_top_worst}\
promedio peores 10 ponderados>:{mean_of_top_worst_w}')
# Out:
# promedio de empresas top 10 : 4.426600642577528 promedio de empresas top 10 ponderadas: 3.661245834347464promedio peores 10: 2.7139091471911327promedio peores 10 ponderados>:3.6104101141824927

# %%
top10 = top_ten['firm'].values
top10_w = top_ten_weighted['firm'].values
worst10_w = selected_rows['firm'].values
worst_10 = top_worst['firm'].values


top_bottom = [i for j in [top10, top10_w, worst10_w, worst_10 ] for i in j]

# %%
len(top_bottom)
# Out:
# 41

# %%
top10_w = top_ten_weighted['firm'].values

# %%
ranking = df.loc[df['firm'].isin(top_bottom)]

ranking['ranking']= np.nan

print(ranking.shape)
# Out:
# (174686, 20)
# <ipython-input-86-1889d686c325>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ranking['ranking'].loc[df['firm'].isin(top10)] = 'Top 10 Firmas'
ranking['ranking'].loc[df['firm'].isin(top10_w)]= 'Top 10 Ponderado'
ranking['ranking'].loc[df['firm'].isin(worst_10)]= 'Peores 10 Firmas'
ranking['ranking'].loc[df['firm'].isin(worst10_w)]= 'Peores 10 Firmas Ponderadas'
# Out:
# <ipython-input-87-0c5bfd49eaa5>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-87-0c5bfd49eaa5>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-87-0c5bfd49eaa5>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-87-0c5bfd49eaa5>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ranking
# Out:
#                          firm date_review                        job_title  \
# 0       AFH-Wealth-Management  2015-04-05                              NaN
# 1       AFH-Wealth-Management  2015-12-11             Office Administrator
# 2       AFH-Wealth-Management  2016-01-28             Office Administrator
# 3       AFH-Wealth-Management  2016-04-16                              NaN
# 4       AFH-Wealth-Management  2016-04-23             Office Administrator
# ...                       ...         ...                              ...
# 286121          Goldman-Sachs  2021-06-04                        Associate
# 286122          Goldman-Sachs  2021-06-04  Consumer Service Representative
# 286123          Goldman-Sachs  2021-06-04                Software Engineer
# 286124          Goldman-Sachs  2021-06-04        Software Engineer/Analyst
# 286125          Goldman-Sachs  2021-06-04                   Vice President
#
#                                    current                      location  \
# 0                         Current Employee                           NaN
# 1       Current Employee, more than 1 year  Bromsgrove, England, England
# 2       Current Employee, less than 1 year  Bromsgrove, England, England
# 3                         Current Employee                           NaN
# 4       Current Employee, more than 1 year  Bromsgrove, England, England
# ...                                    ...                           ...
# 286121  Former Employee, more than 3 years                     Bangalore
# 286122   Former Employee, less than 1 year                Richardson, TX
# 286123                    Current Employee                  New York, NY
# 286124  Former Employee, more than 3 years                  New York, NY
# 286125                    Current Employee                           NaN
#
#         overall_rating  work_life_balance  culture_values  \
# 0                    2                4.0             3.0
# 1                    2                3.0             1.0
# 2                    1                1.0             1.0
# 3                    5                2.0             3.0
# 4                    1                2.0             1.0
# ...                ...                ...             ...
# 286121               3                3.0             4.0
# 286122               1                2.0             1.0
# 286123               4                4.0             5.0
# 286124               3                2.0             3.0
# 286125               3                NaN             NaN
#
#         diversity_inclusion  career_opp  comp_benefits  senior_mgmt  \
# 0                       NaN         2.0            3.0          3.0
# 1                       NaN         2.0            1.0          4.0
# 2                       NaN         1.0            1.0          1.0
# 3                       NaN         2.0            2.0          3.0
# 4                       NaN         2.0            1.0          1.0
# ...                     ...         ...            ...          ...
# 286121                  4.0         4.0            3.0          4.0
# 286122                  5.0         1.0            1.0          1.0
# 286123                  4.0         4.0            4.0          3.0
# 286124                  4.0         3.0            4.0          3.0
# 286125                  NaN         NaN            NaN          NaN
#
#         recommend  ceo_approv  outlook  \
# 0             1.0         NaN      2.0
# 1             1.0         NaN      2.0
# 2             1.0         NaN      1.0
# 3             1.0         NaN      2.0
# 4             1.0         NaN      1.0
# ...           ...         ...      ...
# 286121        3.0         3.0      3.0
# 286122        NaN         NaN      NaN
# 286123        3.0         NaN      2.0
# 286124        1.0         2.0      2.0
# 286125        NaN         NaN      NaN
#
#                                                  headline  \
# 0                 Young colleagues, poor micro management
# 1                            Excellent staff, poor salary
# 2                         Low salary, bad micromanagement
# 3                           Over promised under delivered
# 4                                  client reporting admin
# ...                                                   ...
# 286121                                      No pay parity
# 286122                    Consumer Service Representative
# 286123                              A good place to start
# 286124                                    Good, not great
# 286125  Good to company to work for if you like indivi...
#
#                                                      pros  \
# 0       Very friendly and welcoming to new staff. Easy...
# 1           Friendly, helpful and hard-working colleagues
# 2       Easy to get the job even without experience in...
# 3                                 Nice staff to work with
# 4                   Easy to get the job, Nice colleagues.
# ...                                                   ...
# 286121  Good environment, culture, atmosphere and oppo...
# 286122  Very Secure. Security team in the building is ...
# 286123  As far as Engineering goes, I really enjoy the...
# 286124  +Intelligent workers amidst the masses\n+Many ...
# 286125                   Open door culture policy is good
#
#                                                      cons industry  \
# 0         Poor salaries, poor training and communication.  Finance
# 1       Poor salary which doesn't improve much with pr...  Finance
# 2       Very low salary, poor working conditions, very...  Finance
# 3                No career progression and salary is poor  Finance
# 4       Abysmal pay, around minimum wage. No actual tr...  Finance
# ...                                                   ...      ...
# 286121                No pay parity, difference in salary  Finance
# 286122  Horrible work environment. Prepare to hate you...  Finance
# 286123  If your main concern is money, you might as we...  Finance
# 286124  -Internal tech can be a burden, but required f...  Finance
# 286125  to much weightage for NAPA (freshers) and for ...  Finance
#
#                  ranking
# 0       Peores 10 Firmas
# 1       Peores 10 Firmas
# 2       Peores 10 Firmas
# 3       Peores 10 Firmas
# 4       Peores 10 Firmas
# ...                  ...
# 286121  Top 10 Ponderado
# 286122  Top 10 Ponderado
# 286123  Top 10 Ponderado
# 286124  Top 10 Ponderado
# 286125  Top 10 Ponderado
#
# [174686 rows x 20 columns]

# %%
ranking_by_firm = ranking.groupby(['firm', 'ranking'],as_index=False)['overall_rating','culture_values','senior_mgmt','recommend','career_opp', 'outlook' ].agg(['mean']).reset_index()

# %%
ranking_by_firm.columns= ranking_by_firm.columns.get_level_values(0)

# %%
ranking_by_firm
# Out:
#                                                  firm  \
# 0                               AFH-Wealth-Management
# 1                                               Abcam
# 2                              Achieving-for-Children
# 3                                         ActionCOACH
# 4                                    American-Express
# 5                                     Angard-Staffing
# 6                                       Anglian-Water
# 7                                               Apple
# 8                                             Arcadia
# 9                                          BNY-Mellon
# 10                                     Babylon-Health
# 11                                   Bain-and-Company
# 12                              Barchester-Healthcare
# 13                                           Barclays
# 14                                         Barnardo-s
# 15                                    Boots-Opticians
# 16                            Boston-Consulting-Group
# 17                                             Capita
# 18                                         CarShop-UK
# 19                                               Citi
# 20                                          CityFibre
# 21                                   Colosseum-Dental
# 22                                   Creative-Support
# 23                                       Curtis-Banks
# 24                                           Deloitte
# 25                                      Deutsche-Bank
# 26                                          Diligenta
# 27                                    ENABLE-Scotland
# 28                                                 EY
# 29  Engineering-and-Physical-Sciences-Research-Cou...
# 30                                           Equiniti
# 31                           Four-Seasons-Health-Care
# 32                                            Gateley
# 33                                    GlaxoSmithKline
# 34                                      Goldman-Sachs
#
#                         ranking  overall_rating  culture_values  senior_mgmt  \
# 0              Peores 10 Firmas        2.904762        2.964912     2.807018
# 1                 Top 10 Firmas        4.406897        4.550000     4.208633
# 2                 Top 10 Firmas        4.333333        4.000000     4.200000
# 3                 Top 10 Firmas        4.283333        4.363636     4.145455
# 4              Top 10 Ponderado        3.862223        3.954721     3.423925
# 5   Peores 10 Firmas Ponderadas        2.788991        2.500000     2.506494
# 6                 Top 10 Firmas        4.468635        4.396078     4.156863
# 7              Top 10 Ponderado        4.048257        4.139669     3.517469
# 8   Peores 10 Firmas Ponderadas        3.003017        2.774621     2.638577
# 9              Top 10 Ponderado        3.119608        3.092668     2.664505
# 10  Peores 10 Firmas Ponderadas        3.044811        3.055703     2.568733
# 11                Top 10 Firmas        4.559757        4.648232     4.365917
# 12  Peores 10 Firmas Ponderadas        2.879213        2.918495     2.668770
# 13             Top 10 Ponderado        3.584037        3.517343     3.009821
# 14  Peores 10 Firmas Ponderadas        3.046921        3.229965     2.489362
# 15  Peores 10 Firmas Ponderadas        3.012945        2.869403     2.405904
# 16                Top 10 Firmas        4.301789        4.254480     3.905182
# 17  Peores 10 Firmas Ponderadas        2.879848        2.735894     2.521230
# 18                Top 10 Firmas        4.651163        4.597510     4.576763
# 19             Top 10 Ponderado        3.479705        3.382353     2.991029
# 20                Top 10 Firmas        4.441558        4.364865     4.175676
# 21             Peores 10 Firmas        2.916667        2.852941     2.823529
# 22  Peores 10 Firmas Ponderadas        2.257778        2.472081     2.139175
# 23             Peores 10 Firmas        2.425926        2.489796     2.265306
# 24             Top 10 Ponderado        3.779091        3.761684     3.379636
# 25             Top 10 Ponderado        3.456182        3.306174     2.939778
# 26  Peores 10 Firmas Ponderadas        2.363636        2.195652     2.072464
# 27             Peores 10 Firmas        2.761905        2.558824     2.205882
# 28             Top 10 Ponderado        3.733309        3.712703     3.337520
# 29                Top 10 Firmas        4.294118        4.222222     3.800000
# 30  Peores 10 Firmas Ponderadas        3.031250        2.991597     2.789030
# 31  Peores 10 Firmas Ponderadas        2.960366        2.901695     2.671233
# 32                Top 10 Firmas        4.525424        4.596154     4.423077
# 33             Top 10 Ponderado        3.702560        3.655172     3.075610
# 34             Top 10 Ponderado        3.847487        3.716617     3.453915
#
#     recommend  career_opp   outlook
# 0    1.925926    2.872727  2.285714
# 1    2.757143    4.108696  2.804348
# 2    2.600000    4.200000  2.750000
# 3    2.730769    4.145455  2.708333
# 4    2.583520    3.532790  2.440083
# 5    1.902439    1.860759  1.782609
# 6    2.786561    4.203922  2.779116
# 7    2.634394    3.513496  2.636755
# 8    1.926148    2.601490  1.725610
# 9    2.047658    2.796794  2.136825
# 10   2.010870    2.920000  2.089674
# 11   2.880219    4.625932  2.892127
# 12   1.881250    2.990596  2.003300
# 13   2.380577    3.325022  2.282570
# 14   1.969697    2.650685  1.920635
# 15   1.848485    2.727941  1.894737
# 16   2.777154    4.360858  2.823239
# 17   1.887662    2.656431  2.015326
# 18   2.835391    4.553719  2.857741
# 19   2.329455    3.360658  2.332587
# 20   2.718310    4.175676  2.857143
# 21   1.937500    2.823529  2.033333
# 22   1.543590    2.296482  1.661111
# 23   1.622222    2.326531  1.840909
# 24   2.563279    3.894329  2.591026
# 25   2.284234    3.253968  2.064540
# 26   1.535433    1.920290  1.717949
# 27   1.687500    2.388889  1.928571
# 28   2.555707    3.913638  2.578600
# 29   2.600000    4.300000  2.800000
# 30   2.054054    2.812500  2.145540
# 31   1.903448    2.897959  1.940959
# 32   2.882353    4.285714  2.869565
# 33   2.454761    3.305842  2.286351
# 34   2.526769    3.841644  2.511679

# %%
pp = sns.pairplot(ranking_by_firm, hue='ranking', size=2.5, aspect=1.8,

                  plot_kws=dict(edgecolor="black", linewidth=0.5))
fig = pp.fig
fig.subplots_adjust(top=0.93, wspace=0.3)
t = fig.suptitle('Atributos de Compañias por su Overall Ranking', fontsize=20)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2100: UserWarning:
#
# The `size` parameter has been renamed to `height`; please update your code.

# %%
top_ten_pond = ranking.loc[ranking['ranking']=='Top 10 Ponderado']

# %%
data = ranking.loc[ranking['ranking'].isin(['Top 10 Firmas','Peores 10 Firmas'])]

ax= sns.catplot(
    data=data, x="culture_values", y='firm',
    kind="box", col="ranking", orient='h',
    color='#59AA7B'
)

# %%
data = ranking.loc[ranking['ranking'].isin(['Top 10 Ponderado','Peores 10 Firmas Ponderadas'])]

sns.catplot(
    data=data, x="culture_values", y='firm',
    kind="box", col="ranking", orient='h',
   color='#59AA7B'
)

# %%
fig = make_subplots(rows=5, cols=2, subplot_titles= top10)



# Populate each subplot with Spider/Radial bar chart
i = 10
c= 1
r= 0
for empresa in top10:


  if i % 2 == 0:
      row_num = r+1
      col_num = 1
      r= r+1

  if i == 10:
    row_num = 1
    col_num = 1

  if i % 2 != 0:
      row_num = r
      col_num = 2

  if i == 0:
    col_num = 2
    row_num = 10


  i= i-1
  empresa = top_ten[top_ten['firm'] == empresa]

  mean_df = empresa.loc[:, (slice(None), 'mean')]
  mean_df.columns = mean_df.columns.get_level_values(0)
  values = mean_df.values.flatten()
  features = mean_df.columns

  fig.add_trace(
      go.Bar(
          x=features,
          y=values,
      ),
      row=row_num,
      col=col_num
  )

fig.update_layout(
    barmode='group',
    height=2000,
    width=1000,
    title_text="Distribución de Atributos del Top 10",
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="574f6c72-dbaf-4f49-900d-1174f2979ed5" class="plotly-graph-div" style="height:2000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("574f6c72-dbaf-4f49-900d-1174f2979ed5")) {                    Plotly.newPlot(                        "574f6c72-dbaf-4f49-900d-1174f2979ed5",                        [{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[4.651162790697675,4.597510373443983,4.576763485477178,2.8353909465020575,4.553719008264463,2.8577405857740588],"type":"bar","xaxis":"x","yaxis":"y"},{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[4.559757107369583,4.648232411620581,4.365917236884979,2.8802190280629705,4.625931928687196,2.8921271763815293],"type":"bar","xaxis":"x2","yaxis":"y2"},{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[4.52542372881356,4.596153846153846,4.423076923076923,2.8823529411764706,4.285714285714286,2.869565217391304],"type":"bar","xaxis":"x3","yaxis":"y3"},{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[4.468634686346864,4.396078431372549,4.1568627450980395,2.7865612648221343,4.203921568627451,2.7791164658634537],"type":"bar","xaxis":"x4","yaxis":"y4"},{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[4.441558441558442,4.364864864864865,4.175675675675675,2.7183098591549295,4.175675675675675,2.857142857142857],"type":"bar","xaxis":"x5","yaxis":"y5"},{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[4.406896551724138,4.55,4.2086330935251794,2.757142857142857,4.108695652173913,2.8043478260869565],"type":"bar","xaxis":"x6","yaxis":"y6"},{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[4.333333333333333,4.0,4.2,2.6,4.2,2.75],"type":"bar","xaxis":"x7","yaxis":"y7"},{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[4.301788805539527,4.254480286738351,3.905181918412348,2.7771543086172343,4.360858493997817,2.82323912068192],"type":"bar","xaxis":"x8","yaxis":"y8"},{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[4.294117647058823,4.222222222222222,3.8,2.6,4.3,2.8],"type":"bar","xaxis":"x9","yaxis":"y9"},{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[4.283333333333333,4.363636363636363,4.1454545454545455,2.730769230769231,4.1454545454545455,2.7083333333333335],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555 ...

# %%
fig = make_subplots(rows=5, cols=2, subplot_titles= worst_10)



# Populate each subplot with Spider/Radial bar chart
i = 10
c= 1
r= 0
for empresa in worst_10:


  if i % 2 == 0:
      row_num = r+1
      col_num = 1
      r= r+1

  if i == 10:
    row_num = 1
    col_num = 1

  if i % 2 != 0:
      row_num = r
      col_num = 2

  if i == 0:
    col_num = 2
    row_num = 10


  i= i-1
  empresa = top_worst[top_worst['firm'] == empresa]

  mean_df = empresa.loc[:, (slice(None), 'mean')]
  mean_df.columns = mean_df.columns.get_level_values(0)
  values = mean_df.values.flatten()
  features = mean_df.columns

  fig.add_trace(
      go.Bar(
          x=features,
          y=values,
      ),
      row=row_num,
      col=col_num
  )

fig.update_layout(
    barmode='group',
    height=2000,
    width=1000,
    title_text="Distribución de Atributos de las 10 peores Empresas",
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2f7fccd9-e58c-4af1-a649-bebb700ab992" class="plotly-graph-div" style="height:2000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f7fccd9-e58c-4af1-a649-bebb700ab992")) {                    Plotly.newPlot(                        "2f7fccd9-e58c-4af1-a649-bebb700ab992",                        [{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[2.2577777777777777,2.472081218274112,2.1391752577319587,1.5435897435897437,2.2964824120603016,1.6611111111111112],"type":"bar","xaxis":"x","yaxis":"y"},{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[2.3636363636363638,2.1956521739130435,2.072463768115942,1.5354330708661417,1.9202898550724639,1.7179487179487178],"type":"bar","xaxis":"x2","yaxis":"y2"},{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[2.425925925925926,2.489795918367347,2.2653061224489797,1.6222222222222222,2.326530612244898,1.8409090909090908],"type":"bar","xaxis":"x3","yaxis":"y3"},{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[2.761904761904762,2.5588235294117645,2.2058823529411766,1.6875,2.388888888888889,1.9285714285714286],"type":"bar","xaxis":"x4","yaxis":"y4"},{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[2.7889908256880735,2.5,2.5064935064935066,1.9024390243902438,1.860759493670886,1.7826086956521738],"type":"bar","xaxis":"x5","yaxis":"y5"},{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[2.8792134831460676,2.9184952978056424,2.668769716088328,1.88125,2.9905956112852663,2.0033003300330035],"type":"bar","xaxis":"x6","yaxis":"y6"},{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[2.8798479087452473,2.7358936484490397,2.5212298682284042,1.8876623376623376,2.6564310544611818,2.0153256704980844],"type":"bar","xaxis":"x7","yaxis":"y7"},{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[2.9047619047619047,2.9649122807017543,2.807017543859649,1.9259259259259258,2.8727272727272726,2.2857142857142856],"type":"bar","xaxis":"x8","yaxis":"y8"},{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[2.9166666666666665,2.8529411764705883,2.823529411764706,1.9375,2.823529411764706,2.033333333333333],"type":"bar","xaxis":"x9","yaxis":"y9"},{"x":["overall_rating","culture_values","senior_mgmt","recommend","career_opp","outlook"],"y":[2.9603658536585367,2.9016949152542373,2.671232876712329,1.903448275862069,2.8979591836734695,1.9409594095940959],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111 ...

# %% [markdown]
# ### Análisis Univariado: Senior_mgmt

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-74ec1a448b62> in <cell line: 4>()
#       2
#       3
# ----> 4 fig.add_trace(go.h(
#       5             x=X['senior'],
#       6             y=corr_overall_rating['index'],
#
# /usr/local/lib/python3.10/dist-packages/plotly/graph_objects/__init__.py in __getattr__(import_name)
#     297                 return FigureWidget
#     298
# --> 299         return orig_getattr(import_name)
#
# /usr/local/lib/python3.10/dist-packages/_plotly_utils/importers.py in __getattr__(import_name)
#      37             return getattr(class_module, class_name)
#      38
# ---> 39         raise AttributeError(
#      40             "module {__name__!r} has no attribute {name!r}".format(
#      41                 name=import_name, __name__=parent_name
#
# AttributeError: module 'plotly.graph_objects' has no attribute 'h'
